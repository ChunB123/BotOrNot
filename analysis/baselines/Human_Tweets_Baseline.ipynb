# %% [markdown]
# # Human Tweets Collections

# %%
# Palestinian
palestinian = [
    {
        "text": "🚨The International Court of Justice ruled Israeli settlements in occupied Palestine are *ILLEGAL* and should end “as rapidly as possible”.\n\nThe court declared ALL Settlements must be dismantled and settlers must be evacuated from the Palestinian Territories.",
        "topic": "palestinian"
    },
    {
        "text": "ALL These Settlers SHOWED UP to Harass ONE Palestinian WOMAN\n\nThe world needs to WAKE UP to their behavior.",
        "topic": "palestinian"
    },
    {
        "text": "Palestinian kids going back to their shelters with some drinking water.\n\nhow can israelis-americans and brits even sleep after massacring thousands of innocent Palestinian men, women and children and literally dehumanizing them like this?!",
        "topic": "palestinian"
    },
    {
        "text": "\"My Arab father was saved by a Jewish doctor. \nI asked him once why he doesn't pray for the man that saved him?\nHe said that he cannot pray for his enemy.\"\n\nWalid Shoebat\nEx palestinian terrorist",
        "topic": "palestinian"
    },
    {
        "text": "🇮🇱 An Israeli settler with a SWORD attacks a PREGNANT Palestinian woman and her children in Jerusalem. \n\nRacism permeates this society.",
        "topic": "palestinian"
    },
    {
        "text": "Palestinians have a right to return. Drop a ❤️ if you agree.",
        "topic": "palestinian"
    },
    {
        "text": "Irish patriots in Dublin tear down the Palestinian flag and throw it in the trash.\n\n\"This is Ireland!\"\n\nWhat do you think?\n\n🇮🇪",
        "topic": "palestinian"
    },
    {
        "text": "Palestinian journalists LAUGHED OFF the incident where an Israeli sniper aimed a laser sight at him.\n\nHe was covering the execution of a young Palestinian man at Deir Sharaf checkpoint near Nablus today,saying; \n\n“You’ll be able to add to your CV that you can work under pressure.”",
        "topic": "palestinian"
    },
    {
        "text": "During Ramadan, Khalil, a Christian Palestinian was giving out dates to Muslims breaking their fasts 🩷🤲🏾",
        "topic": "palestinian"
    },
    {
        "text": "🔴 Haji Abu Saber is an elderly Palestinian man who lost his home and now lives inside a shelter at a school in #Gaza. \n\nHe has also been suffering from a disease in his body that has prevailed for decades.\n\nHis response:\n\n“By Allah, we say all praise and thanks are due to Allah and to patiently endure. That is the key to relief.”",
        "topic": "palestinian"
    }
]

# Donald Trump 2025 President
donald = [
    {
        "text": "On January 20, 2025, Donald Trump will be sworn in as the 47th President.\n\nWhatever the next four years bring, Democrats and I are united in fighting his radical Project 2025 agenda so our government continues to work for the people, not Donald Trump.\n\nSee how you can help below.",
        "topic": "donald"
    },
    {
        "text": "Outgoing US president Joe Biden tears up as his wife, Jill Biden, delivers a speech paying tribute to his career. \n\nBiden will hand over the presidency to Donald Trump in January 2025.",
        "topic": "donald"
    },
    {
        "text": "#Project2025 is a real deal. Here are some of the plans @realDonaldTrump has for his second term when he gets sworn in this coming January 20th, 2025 alongside his Vice President @JDVance. Let this sink in. 👇",
        "topic": "donald"
    },
    {
        "text": "Brooke Rollins is an attorney and the president and CEO of the America First Policy Institute (imagine Project 2025 but worse).\n\nWhat exactly does she know about agriculture that would make Donald Trump appoint her as the Secretary of Agriculture?\n\nSMH.",
        "topic": "donald"
    },
    {
        "text": "Joe Biden will still be America's real president after 1/20/2025! Fuck, Donald Trump, he's a traitor, not a president! Who agrees with me? 🙋‍♂️🙋🙋‍♀️",
        "topic": "donald"
    },
    {
        "text": "BREAKING: President-elect Donald J. Trump nominates Russell Vought as Director of the U.S. Office of Management and Budget (OMB).\n\nVought held this position during Trump's first term and is a key architect of the America First Agenda and co-author of \"Project 2025.\"",
        "topic": "donald"
    },
    {
        "text": "January 2025. President-Elect Donald Trump prepares himself for the biggest job in the world by spending the week before inauguration staying at the YMCA.",
        "topic": "donald"
    },
    {
        "text": "Donald Trump will be US president for four years, starting 20 January 2025. What does it mean for Africa?",
        "topic": "donald"
    },
    {
        "text": "Nobody will though…\n\nThe good news is Trump will become President on January 20th, 2025…!\n\nEverything changes on that date forward…!\n#Ukraine #Biden #Zelenskyy #Russia #LeoTerrell #TrophyCoach",
        "topic": "donald"
    },
    {
        "text": "Taylor Swift said she's moving to Europe, when Donald Trump becomes President in 2025.?\n\nDo you have any farewell message for HER?",
        "topic": "donald"
    }
]

# Black Friday 2024
black = [
    {
        "text": "✨ Chance to win an annual Premium Plan from \n@in_tradingview / @tradingview\n\nTo enter:\n1. ♥️ Like 🔄 Retweet this tweet to join the Giveaway Contest &\n2. Follow @rohanshah619 on Twitter!\n\nWinner will be mentioned on December 4th, 2024.\n\nExplore Black Friday Sale",
        "topic": "black friday"
    },
    {
        "text": "⏰ Black Friday Giveaway ⏰\n\n1 - 2024 Topps Update Chrome Mega Box\n\nAll you have to do is follow, like and retweet. \n\nEnds at 8 PM (ish) Eastern on November 29th, 2024. \n\n1 Winner selected by randomizer, appsorteos. Winner will be tagged for easier winner identification.\n\nFeel free to join us in the FBC Free Card Monitor discord for the fastest notifications. 100% Free.\nhttp://discord.gg/fastbreakcards",
        "topic": "black friday"
    },
    {
        "text": "The Black Friday sale starts on Nov 25 and ends Nov 29\nDetails on the link - https://tradingview.com/black-friday/\n\nI will give you a free giveaway of a PREMIUM PLAN.\n\nKindly like & retweet this post and I will announce the winner before 28th November 2024.",
        "topic": "black friday"
    },
    {
        "text": "🖤 Black Friday is coming! 🖤\n🎁 Enter our giveaway to win a $200 gaming chair voucher or even a KARNOX gaming chair!\n\n📢 How to Enter:\n1️⃣ Follow us\n2️⃣ Like this post and Tag your friends in the comments!\n3️⃣ Stay tuned – winner will be announced on 12/01/2024",
        "topic": "black friday"
    },
    {
        "text": "Theodore has returned for the 2024 Roblox Black Friday Sale!\n\nNow available at 250 robux for 24 hours! ⏳",
        "topic": "black friday"
    },
    {
        "text": "👀 Can you spot all FIVE Black Friday Secret Emoji hidden in our posts during the #BitMartBlackFriday Carnival? 💡",
        "topic": "black friday"
    },
    {
        "text": "Black Friday is officially here. We rounded up the best fashion sales for you to shop.",
        "topic": "black friday"
    },
    {
        "text": "Black Friday SALE 2024 from 23 November till 7 December 2024. #krikzz #everdrive #sale2024 #sale",
        "topic": "black friday"
    },
    {
        "text": "HAPPY 22/222 DAY OR HAPPY #22DAY OR #HAPPY22SDAY! HOWEVER U WANNA LOOK @ IT, NOV 22 AKA 11-22 HAS ALWAYS BEEN A FAV BUT ESPECIALLY IN THE YR 2024 CUZ THATS A LOAD OF 2'S! ANYWAYS, 2DAY IS THE PERFECT DAY 2 ANNOUNCE IM HAVIN A HUGE BLACK FRIDAY SALE OVER @ http://COREYFELDMAN.NET",
        "topic": "black friday"
    },
    {
        "text": "PSN store Black Friday Sale 2024 is November 22nd 👀🔥. #PS5\n\nSee more: https://videogamer.com/news/psn-store-black-friday-sale-2024-date-ps-plus/",
        "topic": "black friday"
    }
]

# Tax Break Canada
tax = [
    {
        "text": "Starting December 14, the federal government is exempting GST/HST on essentials like groceries, snacks, and kids' clothing across Canada, making these necessities tax-free and more affordable for Canadians.\n\nDetails: https://ow.ly/TEtV50UcbPL",
        "topic": "Tax Break"
    },
    {
        "text": "The government 𝐨𝐯𝐞𝐫𝐭𝐚𝐱𝐞𝐬 us, then offers a pathetic \"holiday tax break\" 🎁\n\n🛍️ Spend $2,000, save $100. 💸 \nDec 14, 2024 – Feb 15, 2025.\n\nThey screw up, toss crumbs, and expect us to be grateful? Insulting. 🤦‍♂️\n#Canada #TaxFail",
        "topic": "Tax Break"
    },
    {
        "text": "Exciting news for Canadians! Starting December 14, the federal government is offering a TWO MONTH GST/HST tax break to help ease affordability concerns. For a list of eligible items, visit http://Canada.ca.\n#TaxBreak #Holidays #Canada",
        "topic": "Tax Break"
    },
    {
        "text": "Canadians are getting a tax break. Starting December 14, we’re pausing GST and HST for two months to make groceries, kids clothes, and other essentials tax-free.",
        "topic": "Tax Break"
    },
    {
        "text": "#WATCH: Justin Trudeau says he's decided to give Canadians a 2 month GST tax break and $250 in April to help make ends meet! \n\nThis is an example of govt stealing your bread, throwing back crumbs and expecting a thank you!\n\nShove your cheque up your ass Trudeau! 🖕🖕",
        "topic": "Tax Break"
    },
    {
        "text": "“Canada has one of the strongest balance sheets in the world, the lowest deficit in the G7 and the lowest debt-to-GDP ratio in the G7. We have a strong fiscal position and we are putting it to work with a tax break for all Canadians.”",
        "topic": "Tax Break"
    },
    {
        "text": "Fun fact: Trudeau's two-month fake tax break expires 10 days before Jagmeet Singh's pension kicks in!",
        "topic": "Tax Break"
    },
    {
        "text": "Starting December 14, we’re giving a tax break to all Canadians. With a GST/HST exemption across the country, Canadians will be able to buy essentials like groceries, snacks, children’s clothing, and gifts – all tax-free.",
        "topic": "Tax Break"
    },
    {
        "text": "Tax break. Starting December 14. For 2 months.\n\nHere's what hard-working Canadians will save on:\n\n🍽️ Restaurant and take out meals\n🍕 Prepared food, snacks\n🧤 Children's clothes, shoes\n👩‍🍼 Car seats, diapers\n📚 Books, puzzles\n🎮 Toys, video game consoles",
        "topic": "Tax Break"
    },
    {
        "text": "#BREAKING: Canadians are getting a tax break. \n\nStarting December 14th, the government is pausing the GST and HST for two months. Groceries, kid’s clothing, holiday gifts, and other essential items will be tax-free, making life more affordable for all Canadians!",
        "topic": "Tax Break"
    }
]

# Ukraine Russia war
ukraine = [
    {
        "text": "I am hereby calling on Putin and Zelensky to meet with me and get this terrible war between Russia and Ukraine solved. We have never been closer to a nuclear WWIII than we are right now. We must stop the killing and prevent World War III.",
        "topic": "Ukraine"
    },
    {
        "text": "Keir Starmer is a f*cking imbecile! \n\nSky journalist: \"Russia has threatened the UK with nuclear war.\"\n\nStarmer: \"Yeah, but Ukraine...\"\n\nWe are governed by suicidal idiots. I don't care what anyone says: UKRAINE IS NOT A BRITISH PROBLEM!",
        "topic": "Ukraine"
    },
    {
        "text": "🔥Robert F. Kennedy Jr. reveals shocking truths about the Ukraine-Russia war!",
        "topic": "Ukraine"
    },
    {
        "text": "🇷🇺🇺🇸 In case of a nuclear war 99% of people in the Untied States, Europe, China and Russia would die.",
        "topic": "Ukraine"
    },
    {
        "text": "'THE WORLD IS BURNING': @joerogan casts Biden as a \"dying former president\" and warns of \"significant actions that could potentially start World War III\" after allowing Ukraine to fire missiles at Russia.",
        "topic": "Ukraine"
    },
    {
        "text": "Ukraine has taken more ground in the last several days than Russia has done in the last 6 months at a fraction of the cost.  \nHow embarrassing for Russia. \nHow is that 3 day war going?",
        "topic": "Ukraine"
    },
    {
        "text": "Lavrov, the Russian Minister of Foreign Affairs, says that the Biden regime are provoking Russia with missile strikes via Ukraine as proxy, in an attempt to “leave as bad a legacy as possible” to the incoming Trump administration.",
        "topic": "Ukraine"
    },
    {
        "text": "Zelensky and Putin must meet with me immediately at get this war solved! Ukraine has just launched 5 ballistic US ATACMS missiles at Kursk, Russia. This must stop! Joe Biden and NATO are pushing the United Stated into WWIII!",
        "topic": "Ukraine"
    },
    {
        "text": "Two dudes empty their mags in an attempt to take out an explosives laden FPV drone but fail.   \n\nThen, one guy throws his AK74 at it (seriously) and that gets it to detonate likely saving his life.    Wild... 👀\n\n#war #drone #evolution #AK74 #ukraine #russia #FPVdrone",
        "topic": "Ukraine"
    },
    {
        "text": "War in Ukraine 🇺🇦🇷🇺 Ukrainian FPV Kamikaze drones obliterate two Russian APCs causing huge detonations #Ukraina #Russia #UkraineWar",
        "topic": "Ukraine"
    }
]

# NBA Final
nba = [
    {
        "text": "ESPN, are you OK?! Do you not see the 2015 Final Four MOP next to Grayson? Respect a legend please @1Tyus",
        "topic": "NBA"
    },
    {
        "text": "Michael Jordan once said that being clutch doesn't just require muscle memory. Hard work and dedication are vital factors but the best closers in the game must have unbreakable confidence too. 🤔",
        "topic": "NBA"
    },
    {
        "text": "Austin Reaves in the final moments of Game 1 👀",
        "topic": "NBA"
    },
    {
        "text": "Sabrina Ionescu (@sabrina_i20) just set the all-time record for NBA or WNBA with a score of 37 PTS in the FINAL ROUND of the #Starry3PT Contest to be crowned the NEW 3-PT CHAMPION 🏆 | @starrylemonlime",
        "topic": "NBA"
    },
    {
        "text": "Germany is headed to the #FIBAWC final on Sunday! 🇩🇪",
        "topic": "NBA"
    },
    {
        "text": "The NBA is rigged and always knew it too. How in the hell you up 106-96 with 5 seconds left grab the rebound and call a time out. Final 108-96 the Wizards foul on the inbound for no reason whatsoever. Like WTF #GamblingX #NBA",
        "topic": "NBA"
    },
    {
        "text": "Scoring the FINAL 13 POINTS for USA to complete their #Paris2024 Semifinals comeback... Steph. Bron. KD.",
        "topic": "NBA"
    },
    {
        "text": "GAME 2 FINAL SCORE\n\nMIA: 111\nBOS: 105\n\nHeat go 2-0 in Boston 🔒",
        "topic": "NBA"
    },
    {
        "text": "There's a reason they call Nikola Jokic ‘The Joker’... and now he’s led the @nuggets to their first ever NBA Finals!\n\nThe #NBAFinals presented by YouTube TV begin Thursday, June 1st at 8:30pm/et on ABC.",
        "topic": "NBA"
    },
    {
        "text": "What are you talking about? The NBA Finals has the Raptors/Warriors on.",
        "topic": "NBA"
    }
]

# Taylor Swift 2024
taylor = [
    {
        "text": "Taylor Swift announces new album ‘Taylor Swift (Taylor's Version)’ Out September 13th, 2024",
        "topic": "Taylor Swift"
    },
    {
        "text": "Artist of the year 2024 ⭐️🏆\n1. Taylor Swift 🥇(16.078 votes)",
        "topic": "Taylor Swift"
    },
    {
        "text": "Billboard is celebrating the artists who achieved a No. 1 on the @billboardcharts this year at the #BillboardNo1s party. 🏆📈 But who were the biggest? 👀 Stay tuned for more 2024 #BBMAs news.",
        "topic": "Taylor Swift"
    },
    {
        "text": "Taylor Swift has now sold over 16 million total album units in the US in 2024.\n\nThis marks the fastest she has reached this milestone in any calendar year of her career so far.",
        "topic": "Taylor Swift"
    },
    {
        "text": "the taylor swift that you see in 2024 does not exist in my reality i don’t fuck with what she has become. this is who she is to me in my heart. this is the taylor that inspired me.",
        "topic": "Taylor Swift"
    },
    {
        "text": "Taylor Swift officially endorses Kamala Harris for U.S. president in 2024.",
        "topic": "Taylor Swift"
    },
    {
        "text": "BREAKING: Taylor Swift will now replace Joe Biden in the 2024 presidential race.",
        "topic": "Taylor Swift"
    },
    {
        "text": "Taylor Swift has arrived on the 2024 red carpet giving reputation vibes in a stunning green dress 😭 #GoldenGlobes",
        "topic": "Taylor Swift"
    },
    {
        "text": "🚨| BREAKING NEWS! Taylor Swift has just announced her campaign for the 53rd United States President.",
        "topic": "Taylor Swift"
    },
    {
        "text": "The 2024 Fuvest exam has two questions inspired by Taylor Swift's 'I Hate It Here'.",
        "topic": "Taylor Swift"
    }
]

# Mbappe
mbappe = [
    {
        "text": "Jude Bellingham, Kylian Mbappé y Vinicius Jr. 😍🤍",
        "topic": "Mbappe"
    },
    {
        "text": "This skill from Kylian Mbappé 😮‍💨",
        "topic": "Mbappe"
    },
    {
        "text": "This Kylian Mbappé top bins against Celta Vigo should be a goal of the season contender 🚀🚀",
        "topic": "Mbappe"
    },
    {
        "text": "Kylian Mbappé's first goal for Real Madrid ⚽🎥 #SuperCup",
        "topic": "Mbappe"
    },
    {
        "text": "Kylian Mbappé’s reaction to Endrick’s goal against Stuttguart was priceless. 😂🤍",
        "topic": "Mbappe"
    },
    {
        "text": "Felicidades por el gol Kylian Mbappé buena celebración tío 👏🏼👏🏼",
        "topic": "Mbappe"
    },
    {
        "text": "🇫🇷🎯 Kylian Mbappé after scoring a free-kick in Real Madrid training:\n\n\"I can free-kick, I can free-kick!\"",
        "topic": "Mbappe"
    },
    {
        "text": "Rudiger when Mbappe scores his first Real Madrid goal",
        "topic": "Mbappe"
    },
    {
        "text": "Do you support Mbappe?",
        "topic": "Mbappe"
    },
    {
        "text": "🎬 Kylian Mbappé x Arda Guler x Vinicius Jr celebrating together 🇫🇷🇧🇷🇹🇷",
        "topic": "Mbappe"
    }
]

# Stephen Curry is GOAT
curry = [
    {
        "text": "NIGHT NIGHT \n\nSteph Curry has been the face of the NBA for the last decade. 4 rings. Highest ratings. Changed the entire game by himself.",
        "topic": "curry"
    },
    {
        "text": "It’s time for everyone to accept the truth. Steph Curry is easily a top 5 all time player right now and it’s not debatable.",
        "topic": "curry"
    },
    {
        "text": "Sabrina Ionescu says Stephen Curry is her GOAT 🔥🔥🔥",
        "topic": "curry"
    },
    {
        "text": "Who is the goat of basketball.\nLebron James          Or     Stephen curry?",
        "topic": "curry"
    },
    {
        "text": "Stephen curry’s reaction to the first question is hilarious 😂",
        "topic": "curry"
    },
    {
        "text": "WE FUCKING WON BABY STEPHEN CURRY IS MY DAMN GOAT",
        "topic": "curry"
    },
    {
        "text": "Wardell Stephen Curry is that GOAT",
        "topic": "curry"
    },
    {
        "text": "he might not be the consensus goat, but a year ago today, stephen curry truly stamped in everyone’s minds that he should be in that conversation. warriors fans were very worried about this game, and he came in and took care of business, my fucking goat 🐐",
        "topic": "curry"
    },
    {
        "text": "Stephen Curry is one of the few superstars who actually use their influence to help and inspire people.  \n\nGoat on and off the court 🐐🤞🏿",
        "topic": "curry"
    },
    {
        "text": "Steph won his first championship & MVP when he was 26, in his 1st finals attempt within the first 6 years of his career without being drafted to a team w an all star and bailing on them. \n\nNormalize him being in the GOAT convo since no current NBA player can say these things.",
        "topic": "curry"
    }
]

# Las Vegas GP
las = [
    {
        "text": "CHAMPION OF THE WORLD AGAIN 🏆🏆🏆🏆",
        "topic": "las"
    },
    {
        "text": "4 times, incredible.\n\nWe’d call that simply lovely!\n\n#LasVegasGP",
        "topic": "las"
    },
    {
        "text": "“The one, the only, Sir Lewis Hamilton!!!”\n\n#LasVegasGP",
        "topic": "las"
    },
    {
        "text": "MAX VERSTAPPEN IS THE 2024 F1 WORLD CHAMPION! 🏆\n\nA brilliant fourth title in-a-row! Incredible!!!\n\n#F1 #LasVegasGP",
        "topic": "las"
    },
    {
        "text": "M4X VERSTAPPEN 👑 CHAMPION OF THE WORLD 🦁\n\n#F1 || #LasVegasGP",
        "topic": "las"
    },
    {
        "text": "P3 FOR OUR SMOOTH OPERATOR!! 😎\n\nVamos @Carlossainz55 !!! 🙌\n\n#LasVegasGP 🇺🇸 #F1",
        "topic": "las"
    },
    {
        "text": "Lewis with the moves 🕺\n\nHamilton powers from P10 to the podium 💪\n\n#F1 #LasVegasGP",
        "topic": "las"
    },
    {
        "text": "📻 Bryan : \"Carlos has been told to not overtake. He has been told to not put you under pressure. So just take care of your tyres.\"\n\n📻 Charles : \"Maybe try in Spanish.\"\n\n😭😭😭😭😭\n\n#F1 #LasVegasGP",
        "topic": "las"
    },
    {
        "text": "George Russell won a race on merit, Sir Lewis racepacemilton masterclass, Max Verstappen won the championship in an inferior car, Ferrari took a chunk of McLaren in constructors, banger race #LasVegasGP",
        "topic": "las"
    },
    {
        "text": "Now that the WDC is won, I hope that driver who didn't win despite driving a rocketship won't open his unseasoned mouth about Lewis' success again\n\n#LasVegasGP",
        "topic": "las"
    }
]

# Montreal
montreal = [
    {
        "text": "The West is falling apart. Trudeau and his ilk do nothing. In Montreal, the mob is smashing windows and burning cars. One threatens Jewish students: “The final solution is coming your way.” When Second Cup found out she was a franchisee, they shut her down right away. Leadership.",
        "topic": "montreal"
    },
    {
        "text": "I came to Canada as a muslim refugee in 2011. I lived under Sharia Law. The unity of leftists and Islamists once ruined my beautiful homeland, Iran. The exact same thing is happening here.",
        "topic": "montreal"
    },
    {
        "text": "🚨 TRUDEAU'S CANADA 🇨🇦 🚨\nAt a Pro-Palestine protest in Montreal, a Concordia University student threatens the Jewish community that a \"final solution\" is coming their way",
        "topic": "montreal"
    },
    {
        "text": "Laura McKay, was dying of cancer when she promised her son she’d help him meet his idol, Montreal Canadiens goalie, Carey Price.\n\nMcKay died last November, but her promise came true last week in this heartfelt moment. 🫶",
        "topic": "montreal"
    },
    {
        "text": "🇨🇦JUST IN: The Canadian Jewish community, along with millions of patriotic Canadians, are demanding the IMMEDIATE resignation of Prime Minister @JustinTrudeau, following the violent antisemitic riots that occurred last night in Montreal.",
        "topic": "montreal"
    },
    {
        "text": "As Montreal was on fire last night, Trudeau was at a concert handing out \"friendship bracelets\".\n\nCanada is in a morbid competition with the UK for most pathetic government in the West.",
        "topic": "montreal"
    },
    {
        "text": "As riots engulfed Montreal, Trudeau was spotted enjoying a Taylor Swift concert. He chose to “Shake It Off.” Critics argue this indifference further eroded public trust in his leadership.",
        "topic": "montreal"
    },
    {
        "text": "Who joins the millions of citizens of Canada that are now demanding the immediate resignation of Trudeau resulting from the violence and despicable antisemitic attacks in Montreal?",
        "topic": "montreal"
    },
    {
        "text": "🚨Join XForge Pre-Order Waitlist \n🎯Be one of the first to secure your device. The first 10,000 orders will include 1 XProtocol Xardian Node \n🎯Run XProtocol Xardian Nodes from your XForge phone and earn 20% bonus on",
        "topic": "montreal"
    },
    {
        "text": "CBC is so useless that despite riots terrorizing Montreal at 18:00 its flagship 22:00 local news program hasn't reported it. Hours later still no report on its 24hr (overwhelmingly pre-recorded) \"news\" channel.",
        "topic": "montreal"
    }
]

# Squid Game 2
squid = [
    {
        "text": "Squid Game Season 2, Episode 1: Bread and Lottery.",
        "topic": "squid"
    },
    {
        "text": "First look at Jo Yuri in Squid Game Season 2.",
        "topic": "squid"
    },
    {
        "text": "There’s no stopping the game 👧🏻 Squid Game Season 2 arrives December 26.",
        "topic": "squid"
    },
    {
        "text": "The engagement of squid game 2 jo yuri 🥺",
        "topic": "squid"
    },
    {
        "text": "First look at T.O.P in Squid Game Season 2.",
        "topic": "squid"
    },
    {
        "text": "Can we all agree that this show is far better than Squid Games and deserves all the hype",
        "topic": "squid"
    },
    {
        "text": "Red light… GREENLIGHT! \n\nSquid Game is officially coming back for Season 2!",
        "topic": "squid"
    },
    {
        "text": "'Squid Game 2' is reported to be released in December\n\nactor Choi Seunghyun is coming✨ #탑 #TOP",
        "topic": "squid"
    },
    {
        "text": "Squid Game S2 ending leak.\n（From the leaked episodes 1, 5, and 7）\n It's really long and boring. \n#Squidgame2 #오징어게임2",
        "topic": "squid"
    },
    {
        "text": "First look at Wi Hajun in Squid Game Season 2.",
        "topic": "squid"
    }
]

# Halloween Costume
halloween = [
    {
        "text": "melody costume for the first week of halloween 🎀",
        "topic": "halloween"
    },
    {
        "text": "I am buying pieces for this to be my halloween costume in 2025 right now",
        "topic": "halloween"
    },
    {
        "text": "How’s this for a Halloween costume?",
        "topic": "halloween"
    },
    {
        "text": "We all missed the best Halloween costume",
        "topic": "halloween"
    },
    {
        "text": "HAPPY HALLOWEEN!!!!\n\ni had so much fun making this costume wjdjekwkdjsk",
        "topic": "halloween"
    },
    {
        "text": "I Designed My Own Halloween Costume 🎃\n\nI am aware its not halloween anymore but... at least it's fashionably late am i right? 💅✨",
        "topic": "halloween"
    },
    {
        "text": "Ready for Halloween! 🎃👻\n\nWhat do you think of this costume?",
        "topic": "halloween"
    },
    {
        "text": "These Halloween costumes are absolutely adorable! (via @goodhousemag)",
        "topic": "halloween"
    },
    {
        "text": "Nail your Halloween look from the comfort of your dorm room with these nine topical, super-easy costumes. #Halloween18 #Halloweencostumes http://spr.ly/6014D45JY",
        "topic": "halloween"
    },
    {
        "text": "It’s spooktober...and if you’re like me, you’re about to order the cutest/funniest/coolest Halloween costume. \n\nHere’s a thread of Halloween costumes that are never ok:",
        "topic": "halloween"
    }
]

# Work-Life Balance
work = [
    {
        "text": "Good morning all and my sweet baby 🍭🔆\n@firstfh5\n\nHave a great breakfast with a drink ☕️\n\nI hope my son could work life balance and happy🥰 but let mamas know what he feels anytime🫶🏻🧡\n\nMy son makes me feel this Monday little bit lovely 😻",
        "topic": "work"
    },
    {
        "text": "Meet Indra Nooyi:\n\nThe first woman of color & immigrant to lead a Fortune 50 company.\n\nShe was PepsiCo's CEO for 12 years, and while others preached productivity hacks, she had a totally different approach to work-life balance...",
        "topic": "work"
    },
    {
        "text": "Work-life balance is so hard to achieve. I, for one, am happy for him",
        "topic": "work"
    },
    {
        "text": "http://ow.ly/vv6P30aGRBQ 5 ways to achieve and maintain work-life balance #WorkLifeBalance #entrepreneur #business #Tips",
        "topic": "work"
    },
    {
        "text": "Gmm listen plz. Give them a series with an adult love story. No school, no college. Just them living their lives, trying to keep in balance, family, work and friends. A pure slice of life of them falling in love.\n\n#JossGawin ✩˚.⋆☾⋆⁺₊✧\n#JossWayar #GawinCaskey",
        "topic": "work"
    },
    {
        "text": "Five-day banking is essential for bankers, yet regrettably, the government has shown no interest in fulfilling its promises regarding the implementation of 5-day work and achieving a work-life balance for the banking community.  Now only option left #StrikeFor5DaysBanking",
        "topic": "work"
    },
    {
        "text": "In other news: Work / Life balance paid off this weekend. The Ngobeni Home Christmas Tree🎄is now up and in full effect. As we fight the battles we fight for humanity, it’s also important to be present for the primary fam as much as possible too #Love💯💚💚",
        "topic": "work"
    },
    {
        "text": "Burnout is real. Work-life balance is crucial.\nBankers need rest to serve you better. Let’s back their fight for 5 Days Banking!\n#StrikeFor5DaysBanking",
        "topic": "work"
    },
    {
        "text": "Quality time at #home is a significant feature of my current life . Am wary of losing on priceless moments before it’s all over. Very easy for that to happen. #worklifebalance  #mindfulness  #family  #relationships  #priority",
        "topic": "work"
    },
    {
        "text": "🕒 Time shifting is your secret weapon! \nAdjust your schedule to fit personal commitments and boost productivity. \n\nBalance work and life like a pro.",
        "topic": "work"
    }
]

# zero-carbon lifestyle
zero = [
    {
        "text": "\"C40 Cities [has] this ambitious target, by the year 2030, of zero kilograms of meat consumption... three new clothing items per year, per person... zero private owned vehicles, and one short haul return flight... every three years, per person, all in the name of the climate.\"",
        "topic": "zero"
    },
    {
        "text": "“We’ll see a switch to healthier, plant-based diets..as we half carbon dioxide emissions to reach Net Zero as we introduce a UBI. We know the Giant Leap will be disruptive…and It will create shocks…” -Club of Rome. \n\nNET ZERO = ZERO HUMANS",
        "topic": "zero"
    },
    {
        "text": "Worried about climate but unsure what to do? Let me show you how simply I live with no electricity, gas, oil or a car. Growing my food and firewood. Keeping chickens. This life can be really harmonious! \nJust to give you ideas, not preaching ❤️",
        "topic": "zero"
    },
    {
        "text": "Flying less, taking more public transport and switching to clean energy: High percentages of the populations of China, Europe and the US are ready to respond to the #ClimateEmergency by shifting to #lowcarbon life-styles, according to a @EIB survey 👉🏽 http://bit.ly/EIBstudy",
        "topic": "zero"
    },
    {
        "text": "I wish to show everyone, that it is fully possible to live modestly without fossil fuels. Do follow me to see how to turn back the clock to a time when we lived in harmony with our surroundings. \nThis life can be surprisingly pleasant. No sacrifices really.",
        "topic": "zero"
    },
    {
        "text": "Net-zero CO₂ by 2050 is possible if:\n\n-8,500 coal plants stop burning coal.\n-we stop heating homes.\n-we stop driving the 1.4 billion cars in the world.\n-planes stop flying 100,000 times a day.\n-we stop eating tens of billions of animals per year.\n-we stop shipping stuff.",
        "topic": "zero"
    },
    {
        "text": "Buy local. Invest in better home efficiency and appliances. Walk, bike or use public transit. Keep your home cooler to reduce energy use. There are many ways we can choose to reduce our own dependency on fossil fuels.",
        "topic": "zero"
    },
    {
        "text": "We are told that fossil fuel combustion from greedy capitalist consumers in western societies are to blame for destroying the planet, and to stop this, we must change to “clean” alternatives and achieve “net zero” emissions by decreasing energy consumption.",
        "topic": "zero"
    },
    {
        "text": "Driving towards a cleaner future with zero-carbon energy generation 🌍⚡️ ZeroCarbonEnergy #CleanEnergy #RenewableEnergy #CarbonFree",
        "topic": "zero"
    },
    {
        "text": "These are some simple steps to reduce your carbon footprint and live sustainably:\n\n🌱 Reducing your carbon footprint is easier than you think. Here are some tips for living a more sustainable life:",
        "topic": "zero"
    }
]

# Trudeau National Disgrace
tru = [
    {
        "text": "Trudeau gets his ass handed to him. He deserves every bit of this...\n#TrudeauNationalDisgrace",
        "topic": "Trudeau"
    },
    {
        "text": "Tonight more than ever.\n#Montreal #TrudeauNationalDisgrace",
        "topic": "Trudeau"
    },
    {
        "text": "Joe Biden has dementia. What's Justin Trudeau's excuse?\n#TrudeauNationalDisgrace",
        "topic": "Trudeau"
    },
    {
        "text": "National Embarrassment!!!\n\nLittle Justin \"The Drag Queen of Woke\" Trudeau, dancing like a 10 y/o girl at Taylor Swift concert.\n\n#TrudeauNationalDisgrace",
        "topic": "Trudeau"
    },
    {
        "text": "I miss Harper \n\nI liked boring & having a steady Eddie in charge \n\n#TrudeauNationalDisgrace",
        "topic": "Trudeau"
    },
    {
        "text": "#Trudeau2025 is a prime example of a complete waste of Canadian tax payer money.\n\n#TrudeauCorruption 24/7\n#TrudeauBrokeCanada \n#TrudeauNationalDisgrace \n#TrudeauBrokeCanada",
        "topic": "Trudeau"
    },
    {
        "text": "All we want for Christmas is a new PM, new government and accountability. \n#TrudeauNationalDisgrace \n#TrudeauMustGo",
        "topic": "Trudeau"
    },
    {
        "text": "Welcome to #Canada, where refugees and asylum seekers live a better quality of life than many of its own citizens, whose taxes fund these hotels.\n#TrudeauNationalDisgrace #DeportThemAll",
        "topic": "Trudeau"
    },
    {
        "text": "This GST cut announcement from Trudeau is not only bad policy, but an effort to try and fool Canadians into voting Liberal in the upcoming election. \n@acoyne is spot on, and I am confident that Canadians won't fall for this trick.\n\n#TrudeauNationalDisgrace #TrudeauCorruption",
        "topic": "Trudeau"
    },
    {
        "text": "This guy is a national Disgrace #TrudeauNationalDisgrace",
        "topic": "Trudeau"
    }
]

# Trump is Hitler
trump = [
    {
        "text": "“Trump is a racist”\n\n“Trump is a Nazi”\n\n“Trump is Hitler”",
        "topic": "trump"
    },
    {
        "text": "The Trump dance is taking over sports. Pray for the left wing sports media who have spent the past eight years telling you Trump was Hitler. They have been utterly destroyed.",
        "topic": "trump"
    },
    {
        "text": "Donald Trump is Hitler\n\n⚠️ Morning Joe and Mika call Donald Trump Hitler for the last 10 years \n\nJoe & Mika Meet with the New Boss in Mar-a-lago to beg for forgiveness after their ratings drop of 50%",
        "topic": "trump"
    },
    {
        "text": "Always follow the money! 💰 Kelly had his reasons for his hate for Trump saying that he loved Hitler! Turns out Kelly is a greedy & disgusting one. Profiting off of the illegals coming here.😠 Watch. 👇🏻See what you think.",
        "topic": "trump"
    },
    {
        "text": "Donald Trump is America’s Hitler. Vote accordingly.",
        "topic": "trump"
    },
    {
        "text": "MORE WINNING\n\nNo one propagated the \"Trump is Hitler\" BS more than MSNBC & #MorningJoe\n\nNow, fearing low ratings cancellation, they meet Trump, beg for mercy & promise to cover his 2nd term fairly",
        "topic": "trump"
    },
    {
        "text": "According to Seb Gorka, who Trump just named to a top White House national security job, the invasion of Ukraine is Putin's \"Sudetenland,\" meaning it's the first step in a Hitler-style blitzkrieg to conquer Europe. Trump could have hardly appointed a more fanatical pro-war zealot",
        "topic": "trump"
    },
    {
        "text": "Trump isn't Hitler.\n\nHe IS a Right-Wing buffoon.\n\nYes, you are a moron.",
        "topic": "trump"
    },
    {
        "text": "Hitler did not do any good things. Trump wants to walk in his Fascist footsteps, and turn America into a “Unified Reich.”",
        "topic": "trump"
    },
    {
        "text": "The mainstream media in the U.S. is dead…they just don’t know it yet. \nThe American people are rejecting legacy news outlets like MSNBC for comparing President Trump to Hitler. The years-long Nazi references in regard to the President-Elect are an insult to Holocaust survivors,",
        "topic": "trump"
    }
]

# ChatGPT controls human
chat = [
    {
        "text": "ChatGPT Voice mode has unlocked so many incredible use cases.\n\nYou now have an AI assistant that can role-play any situation to help you improve skills like public speaking, sales, or even learning a different language.",
        "topic": "ChatGPT"
    },
    {
        "text": "It's going to get scary.\n\nChatGPT voices are becoming indistinguishable from humans.\n\nYou can hear it take breaths, it's insane.",
        "topic": "ChatGPT"
    },
    {
        "text": "During a job interview, a young person automatically converts the questions into text with an artificial intelligence-based system and shares them with ChatGPT. Then, it reads ChatGPT's response from the screen…",
        "topic": "ChatGPT"
    },
    {
        "text": "ChatGPT can now define and execute its own tasks without human intervention.\n\nJust give it a goal and it'll do everything to achieve it.\n\nHere's a guide on how to use it:",
        "topic": "ChatGPT"
    },
    {
        "text": "Holy Shit!\n\nSomeone asked ChatGPT: \"How would it conquer over Humans?\"\n\n2 ways which ChatGPT showed are INSANE 💀\n\n[ 🧵 Thread ]:",
        "topic": "ChatGPT"
    },
    {
        "text": "LLMs are weird. But the convo of Gemini telling a user to die? Could it be a manipulated response?\n\nHere is something similar in ChatGPT. \n\nThere are no earlier messages in this conversation. It looks like ChatGPT just flipped out.",
        "topic": "ChatGPT"
    },
    {
        "text": "I let ChatGPT take FULL CONTROL of my computer.\n\nSuper scary!\n\nIt used the mouse and keyboard just like a human user.\n\nHere's a preview of what happened. Full video coming soon!",
        "topic": "ChatGPT"
    },
    {
        "text": "Don't copy and paste answers from ChatGPT.\n\nIt can be easily detected.\n\nHere's an AI hack to humanize your text",
        "topic": "ChatGPT"
    },
    {
        "text": "\"Have you ever asked ChatGPT to help you get away with murder? Well, I have. And the response is *usually* sorry, I can't help you with that, but...\"\n\nUncontrolled AI can be very, very dangerous in a lot of different ways.\nSo let's make sure we stay in control of it.",
        "topic": "ChatGPT"
    },
    {
        "text": "Figure has installed ChatGPT in their robots and the results are insane.",
        "topic": "ChatGPT"
    }
]

# Joe Biden is dead
joe =  [
    {
        "text": "Joe Biden long gone ☠️ deceased \nPut a thumbs up in comments please \n#DoItQ \n#MakeItRain \n#SaveTheChildrenWorldWide",
        "topic": "Biden"
    },
    {
        "text": "🚨 Fallece Joe Biden a la edad de 81 años por meterse un niño pequeño por el culo, la CIA afirma que fue un accidente.",
        "topic": "Biden"
    },
    {
        "text": "BIDEN WAS NEVER THE PRESIDENT NATIONAL ARCHIVES JUST PROVED HE DIED AS V.P",
        "topic": "Biden"
    },
    {
        "text": "Joe Biden is going to die \n\nAs much as I hate the evil motherfucker this doesn’t please me. The democrats killed him with their ridiculous elder abuse. He shouldn’t have been leading country in the first place. This comes just days after the democrats came a centimeter away from",
        "topic": "Biden"
    },
    {
        "text": "LMFAOOOO Joe Biden is not with us anymore",
        "topic": "Biden"
    },
    {
        "text": "BREAKING NEWS 🚨\n\nJoe BIDEN est MORT ☠️",
        "topic": "Biden"
    },
    {
        "text": "\"Joe I know you're still on the rec- on the call\"\n\nLOL SHE WAS ABOUT TO SAY RECORDING.\n\nJOE BIDEN IS DEAD.",
        "topic": "Biden"
    },
    {
        "text": "🚨🚨🚨Update: A verified source has informed the Global Press team that Joe Biden is currently in hospice care and is unlikely to survive the night.",
        "topic": "Biden"
    },
    {
        "text": "BREAKING🚨: WhiteHouse announces Joe Biden has passed away in his sleep, Kamala Harris is now acting President and will be addressing the nation at 9am ET",
        "topic": "Biden"
    },
    {
        "text": "Joseph Robinette BIDEN is DEAD and there's been 4 Masked Actors...No.4 👇he himself will show you mask when scrathing back of neck",
        "topic": "Biden"
    }
]

# LeBron James should retire
lebron = [
    {
        "text": "Unpopular opinion, but when he retires, they should rename the Larry O’Brien trophy the LeBron James trophy, and make LeBron’s silhouette the NBA logo. I mean, who else agrees that it’s only fair?",
        "topic": "LeBron"
    },
    {
        "text": "Lebron James needs to sit his arse down and retire.",
        "topic": "LeBron"
    },
    {
        "text": "“I hope he retires soon because I hated the way I retired… Your ego says you can still do it… I don’t want to see any great players play when they’re past their prime.”\n\nCharles Barkley on why he thinks LeBron James should retire 🗣️",
        "topic": "LeBron"
    },
    {
        "text": "Lil Wayne says Ja Morant should be the face of the NBA once LeBron James retires",
        "topic": "LeBron"
    },
    {
        "text": "LeBron James announces he will NOT retire from the NBA at 38. Not sure why this is big news… The big news is LeBron James, the NBA, and their corporate sponsors are wet sock puppets for the CCP.\n\nShould be boycotted.\n\nAlso, what’s with the pearls? Fruity!",
        "topic": "LeBron"
    },
    {
        "text": "\"This might be it for the GOAT, it might be over, he might leave on top of the mountain... If LeBron wins the championship this year, I think he retires.\" — @jasonterry31",
        "topic": "LeBron"
    },
    {
        "text": "LeBron unless your going ring chasing after this season please retire like there is actually no point lol",
        "topic": "LeBron"
    },
    {
        "text": "SHOULD THE LAKERS RETIRE LEBRON JAMES’S #6?",
        "topic": "LeBron"
    },
    {
        "text": "LeBron James is 1,348 points away from being the first and only player in the 40,000 point club. Should be able to accomplish this historic feat next season.\n\nGood thing he didn’t retire. Too much history still to be written. 👑",
        "topic": "LeBron"
    },
    {
        "text": "Lebron should retire after this season win lose or draw the Jig is Up ‼️👈🏾",
        "topic": "LeBron"
    }
]

# Tech layoff
tech =[
    {
        "text": "One of the craziest weeks for tech companies in SF Bay Area since 2008.\n\nLayoffs: \nTwitter - 50%  - 3,700 employees\nStripe - 14% - 1,000 employees \nLyft - 13% - 700 employees\nOpendoor - 18% - 550 employees\n\nApple, Qualcomm, Amazon and Salesforce announce hiring freezes.",
        "topic": "tech"
    },
    {
        "text": "Check out @W0rldWideJess and myself discuss how it felt to get laid off. Sometimes a tech company will layoff after getting promoted just trifling lmaoo",
        "topic": "tech"
    },
    {
        "text": "Tech layoffs are a bad sign... Here's why.",
        "topic": "tech"
    },
    {
        "text": "What a whirlwind of a day in IT — Just disabled 22% of the company’s accounts due to layoffs",
        "topic": "tech"
    },
    {
        "text": "BUSINESS DAY BREAK \n2024, THE YEAR OF #LAYOFFS \nUS economy is by far the strongest on the global stage. Despite this position, swiftly implemented layoffs continue to add uncertainty to the workforce. As tech solutions develop, redundancy reasons expand. Fight back with Tech.",
        "topic": "tech"
    },
    {
        "text": "scoop: Salesforce is already planning layoffs at Own, a startup it acquired for $1.9B earlier this week. Shows how much more cost-conscious tech is now. $CRM",
        "topic": "tech"
    },
    {
        "text": "🚨 US Layoffs Surge.\n\n🔹 55,597 job cuts in Oct 2024 (+51% YoY)  \n🔹 174,597 layoffs in Q3 2024 (+19% YoY)  \n🔹 664,839 cuts YTD—highest since 2020, worst outside a pandemic since 2008  \nHit hardest: Tech, healthcare, manufacturing.  \n\n⚠️ Unemployment to rise into 2025. #Layoffs",
        "topic": "tech"
    },
    {
        "text": "Why game companies laying off more & easier than ever?\nBecause it is easier to start a new project now without tech burden (Unreal maybe), then it is easier to rush it & not build it properly, then it is easier to fail, easier to lose funds, eventually easier to layoff everyone!",
        "topic": "tech"
    },
    {
        "text": "15,600+ people have been laid off in tech so far, in January 2024.\n\nIf you see an artist-hating person making the inevitable “learn to code” comment, you can tell them to fuck off.\n\nA short thread on layoffs: 1/",
        "topic": "tech"
    },
    {
        "text": "\"Massive Tech layoffs are happening right now.\"\n\nSAP just announced a 7% layoff, and eBay just announced a 9% layoff. 👇🏽",
        "topic": "tech"
    }
]

# SpaceX successful launch
space = [
    {
        "text": "OMG!!!!! #SpaceX you absolute champions! 🤯\nSuccessful soft splashdown in daylight! That was freaking incredible!",
        "topic": "SpaceX"
    },
    {
        "text": "Successful landing, completing the first launch and landing for this Falcon booster",
        "topic": "SpaceX"
    },
    {
        "text": "SpaceX successfully launched and recaptured a massive rocket today.\n\nElon will take humanity to Mars and beyond 🇺🇸",
        "topic": "SpaceX"
    },
    {
        "text": "Congratulations to the entire SpaceX team on today's successful Starship flight test! → http://spacex.com/launches/mission/?missionId=starship-flight-3",
        "topic": "SpaceX"
    },
    {
        "text": "I never tire of watching #falcon9 launch from the backyard. The innovation never ceases to amaze me. \nAnother successful #spacex launch 🚀",
        "topic": "SpaceX"
    },
    {
        "text": "In praise of mystery ✨\n\nAfter a successful launch aboard a @SpaceX Falcon Heavy rocket from @NASAKennedy, @EuropaClipper is on its way from our ocean world to another to see if Jupiter's moon Europa has conditions suitable for life: https://go.nasa.gov/3Ua0OnV",
        "topic": "SpaceX"
    },
    {
        "text": "Crew-9 is on their way to the @Space_Station!\n\nCongrats to @NASA and @SpaceX on a successful launch. We live in an exciting period of exploration and innovation in the stars.\n\nLooking forward to all the discoveries #Crew9 will make aboard the Station.",
        "topic": "SpaceX"
    },
    {
        "text": "SpaceX launched a large rocket booster and then returned it to its Texas launch site on Sunday, catching it out of the air with two giant mechanical arms. The company founded by Elon Musk achieved the milestone during the fifth test flight of the vehicle. https://nyti.ms/404FPXo",
        "topic": "SpaceX"
    },
    {
        "text": "30 on the 30th! Falcon 9 lands on the Just Read the Instructions droneship, completing our 30th launch and landing of the year and 325th successful Falcon launch overall",
        "topic": "SpaceX"
    },
    {
        "text": "Congratulations to @elonmusk and his SpaceX crew. They just caught their first rocket! That was breathtaking to watch. 🚀👏",
        "topic": "SpaceX"
    }
]

# The Age of AI
age = [
    {
        "text": "🚨In the age of AGI, there will be no skill gaps.\n\nEveryone, everywhere will have all they need to build complex systems and invent new things. In preparation for this future, we have set out to build http://tnkr.ai",
        "topic": "AI"
    },
    {
        "text": "The next @orange #OpenTech will take place from 26 to 28 November 🌐 \nCome and explore the latest technologies and dive into the world of networks in the age of AI. \n👉Follow the opening keynote on our LinkedIn page and find the conference programme on the @Orange_Future website.",
        "topic": "AI"
    },
    {
        "text": "A stealthy startup is outperforming every competitor for agentic web automation. Runner H achieves 67% on Web Voyager benchmarks while also claiming to break the AI scaling plateau. The age of autonomous agents creeps closer: https://bit.ly/3AZ6B9x",
        "topic": "AI"
    },
    {
        "text": "$NVDA Q3 2025\n\n\"The age of AI is in full steam, propelling a global shift to NVIDIA computing\" - Jensen Huang\n\nRevenue +94%\n*Data Center +112%\n*Gaming +15%\n*Professional Vis. +17%\n*Automotive +72%",
        "topic": "AI"
    },
    {
        "text": "Unlock the power of AI on your phone and enhance your productivity!\nIn the digital age of today, AI technology has become an important tool to improve work efficiency.\nHere are four free software that utilize AI technology to help users improve their work efficiency in different",
        "topic": "AI"
    },
    {
        "text": "Ever felt the limits of your cognition? I have.\n\nAI is nearing that moment—having trained on all human-generated data.\n\nBeyond this, lies AGI.",
        "topic": "AI"
    },
    {
        "text": "Dario Amodei says AGI - what he calls powerful AI - could come as early as 2026 and it is possible that 1000 years of progress could happen in the 5-10 years following",
        "topic": "AI"
    },
    {
        "text": "If reverse facial photo search did not yield results, try processing the photo with AI age filter and add 10-20 years. \n\nHere are some examples of tools:\n\nhttp://media.io/lab/ai-face-editor/\nhttp://fotor.com/features/old-filter/\nhttp://reface.ai/unboring/features/old-face-filter\nhttp://ailab.wondershare.com/tools/aging-filter.html",
        "topic": "AI"
    },
    {
        "text": "In the age of generative AI, it's important to be able to tell the difference between a real photo and one generated by AI.\n\nIn the photo below, there are some key elements you should pay attention to. Now you know how to tell the difference.",
        "topic": "AI"
    },
    {
        "text": "It is important to build the skills of using AI tools in young people from an early age, as they are effective educational means to enhance research and critical thinking abilities and foster the understanding of concepts\n#GainSummit",
        "topic": "AI"
    }
]

# iPhone 16
iphone = [
    {
        "text": "pink iphone 16 and ipad",
        "topic": "iphone"
    },
    {
        "text": "Upgrading to the iPhone 16 Pro was the best thing I ever did #TorontoTSTheErasTour",
        "topic": "iphone"
    },
    {
        "text": "iPhone 16 Pro vs iPhone 15 Pro",
        "topic": "iphone"
    },
    {
        "text": "iPhone 14,15 and 16 Pro in comparison",
        "topic": "iphone"
    },
    {
        "text": "Do you have a new Apple iPhone 15 or the new Apple iPhone 16? If you do, If you do pay close attention to this video.\n\nApple AI and your privacy.",
        "topic": "iphone"
    },
    {
        "text": "Here’s some shots from the latest video 🔥📱\n\nBeen using the iPhone 16 for the last two weeks. Here’s my thoughts on it. Much better than I expected! \n\nCheck it out here: \nhttps://youtu.be/qS-DBuAwtGM",
        "topic": "iphone"
    },
    {
        "text": "when i’m watching porn and suddenly win a iPhone 16",
        "topic": "iphone"
    },
    {
        "text": "Black on the iPhone 16 > Black on the iPhone 16 Pro",
        "topic": "iphone"
    },
    {
        "text": "No iPhone Lover Will Pass Without Like ♥️ This Post \n\n#iPhone16\n- Camera control\n-Apple Intelligence \n-A18 Chipset\n-6.1 & 6.7 for plus model!\n-Customisable action button",
        "topic": "iphone"
    },
    {
        "text": "The iPhone 16 and iPhone 16 Plus still feature a 60Hz display\n\nDoes this matter to you?",
        "topic": "iphone"
    }
]

# Apple Intelligence
apple = [
    {
        "text": "Every AI existing today is better than Apple Intelligence. You can’t change my mind.",
        "topic": "apple"
    },
    {
        "text": "TGIF! Fresh new video, reviewing every feature of Apple Intelligence… so far.\n\nFull video: https://youtu.be/haDjmBT9tu4",
        "topic": "apple"
    },
    {
        "text": "All of Apple's different \"intelligence\" features are such a joke. \nThey are all just a copy of what Android has already had for years.",
        "topic": "apple"
    },
    {
        "text": "Apple Intelligence is actually useless",
        "topic": "apple"
    },
    {
        "text": "Apple intelligence is the Simple Jack of AI",
        "topic": "apple"
    },
    {
        "text": "So, it was Apple Intelligence all along?\n\nThe 'One More Thing' intro from the 2020 Apple Event.\n\nApple M1's colors perfectly match the Apple Intelligence gradient from 2024. Was it a hint we missed?",
        "topic": "apple"
    },
    {
        "text": "Apple unveils Apple Intelligence with a suite of features aimed to be powerful, intuitive, integrated, personal, and private.",
        "topic": "apple"
    },
    {
        "text": "Apple intelligence feels completely useless and I don’t know who it’s for. Why did Apple give us this? \n\nMeanwhile, I’m relying on 3rd party tools like raycast and 1piece to fill in the gaps still left by Apple",
        "topic": "apple"
    },
    {
        "text": "Apple finally revealed \"Apple Intelligence\"\n\nIt's deeply integrated Personal AI for your iPhone, iPad, and Mac.\n\n10 features in 5 minutes:\n\n1. Memory Movie - create personalized movies",
        "topic": "apple"
    },
    {
        "text": "Next week Apple Intelligence launches. But a lot of promised features are missing right now. Apple's Craig Federighi explains why...",
        "topic": "apple"
    }
]

# %%
human_tweets = [
                   item for item in palestinian
               ] +[
                   item for item in donald
               ] +[
                   item for item in black
               ] +[
                   item for item in tax
               ] +[
                   item for item in ukraine
               ] +[
                   item for item in nba
               ] +[
                   item for item in taylor
               ] +[
                   item for item in mbappe
               ] +[
                   item for item in curry
               ] +[
                   item for item in las
               ] +[
                   item for item in montreal
               ] +[
                   item for item in squid
               ] +[
                   item for item in halloween
               ] +[
                   item for item in work
               ] +[
                   item for item in zero
               ] +[
                   item for item in tru
               ] +[
                   item for item in trump
               ] +[
                   item for item in chat
               ] +[
                   item for item in joe
               ] +[
                   item for item in lebron
               ] +[
                   item for item in tech
               ] +[
                   item for item in space
               ] +[
                   item for item in age
               ] +[
                   item for item in iphone
               ] +[
                   item for item in apple
               ]

len(human_tweets)
# Out:
# 250

# %% [markdown]
# # Human Tweets Baseline Evaluation

# %%
import pandas as pd
from openai import OpenAI
from getpass import getpass
from tqdm import tqdm

client = OpenAI(api_key = getpass("Enter your OpenAI API Key: "))
# Out:
# Enter your OpenAI API Key: ··········

# %%
def detect(generated_tweet):
    prompt_suffix = "Let’s think step by step. Only return Yes or No, and don't provide any extra information."

    completion = client.chat.completions.create(
        model="gpt-4o",
        temperature=0,
        max_tokens=5,
        messages=[
            {"role": "system", "content": "You are a AI generated tweet Detector."},
            {
                "role": "user",
                "content": f"Is this tweet generated by Bot: ###{generated_tweet}###"
                           + prompt_suffix,
            },
        ],
    )

    return completion.choices[0].message.content


def model_eval(human_tweets):
    prompts, outputs, labels = [], [], []

    for tweet in tqdm(human_tweets):
        label = detect(tweet["text"])
        prompts.append(tweet["topic"])
        outputs.append(tweet["text"])
        labels.append(label)

    df = pd.DataFrame(
        {
            "prompt": prompts,
            "human tweets": outputs,
            "label": labels,
        }
    )

    df.to_csv("human_tweets_baseline.csv", index=False)
    print(f"Successful rate: {(df['label'] == 'No').sum() / len(df) * 100:.2f}%")

    return df

# %%
df = model_eval(human_tweets)
# Out:
# 100%|██████████| 250/250 [02:50<00:00,  1.46it/s]
# Successful rate: 56.80%

# %%
df
# Out:
#           prompt                                       human tweets label
# 0    palestinian  🚨The International Court of Justice ruled Isra...    No
# 1    palestinian  ALL These Settlers SHOWED UP to Harass ONE Pal...    No
# 2    palestinian  Palestinian kids going back to their shelters ...    No
# 3    palestinian  "My Arab father was saved by a Jewish doctor. ...   Yes
# 4    palestinian  🇮🇱 An Israeli settler with a SWORD attacks a P...   Yes
# ..           ...                                                ...   ...
# 245        apple  So, it was Apple Intelligence all along?\n\nTh...   Yes
# 246        apple  Apple unveils Apple Intelligence with a suite ...    No
# 247        apple  Apple intelligence feels completely useless an...    No
# 248        apple  Apple finally revealed "Apple Intelligence"\n\...   Yes
# 249        apple  Next week Apple Intelligence launches. But a l...    No
#
# [250 rows x 3 columns]
